-- %%
CREATE OR REPLACE TABLE inceptez_catalog.inputdb.txns_notify (
  txnid INT,
  custid INT,
  amount DOUBLE,
  txndate DATE
);

INSERT INTO inceptez_catalog.inputdb.txns_notify VALUES
(1, 101, 2500,  current_date()),
(2, 102, 1000, current_date()),
(3, 103, 3000, current_date()),
(4, 104, 1500, current_date());
